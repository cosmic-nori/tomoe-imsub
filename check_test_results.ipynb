# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PythonPhot import rdpsf

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
work_path = '/home/arima/tomoe/tomoeflash/imsub/test/diff_fits'
psf_path = '/home/arima/tomoe/tomoeflash/imsub/test/diff_fits/rTMQ2202003220028809433_frame001_psf.fits'

# %%
psf_data, psf_header = rdpsf.rdpsf(psf_path)
mean = np.mean(psf_data)
std = np.std(psf_data)
plt.imshow(psf_data, vmin=mean-std, vmax=mean+std, origin='lower')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_76604/3957483499.py in <module>
# ----> 1 psf_data, psf_header = rdpsf.rdpsf(psf_path)
#       2 mean = np.mean(psf_data)
#       3 std = np.std(psf_data)
#       4 plt.imshow(psf_data, vmin=mean-std, vmax=mean+std, origin='lower')
#
# ~/tomoe/PythonPhot/PythonPhot/rdpsf.py in rdpsf(psfname)
#      34     """
#      35
# ---> 36     resid=pyfits.getdata(psfname)
#      37     hpsf = pyfits.getheader(psfname)
#      38
#
# ~/pyenv/versions/anaconda3-2021.05/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/convenience.py in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     207                      extname is None and extver is None)
#     208
# --> 209     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     210     try:
#     211         hdu = hdulist[extidx]
#
# ...

# %% [markdown]
# ## Plot analysis time comparison

# %%
time_file_path = '/home/arima/tomoe/tomoeflash/imsub/test/out_dir/time_funcs.txt'
time_arr = np.loadtxt(time_file_path)

# %%
time_arr.shape
# Out:
# (120, 3)

# %%
df_time = pd.DataFrame(data=time_arr, columns=['hotpants', 'pythonphot', 'sep'])
df_time
# Out:
#      hotpants  pythonphot       sep
# 0    2.137964    0.248713  0.119435
# 1    2.114430    0.229771  0.105717
# 2    2.143881    0.228391  0.105675
# 3    2.116179    0.224253  0.105051
# 4    2.132437    0.228942  0.108626
# ..        ...         ...       ...
# 115  2.121178    0.227162  0.105771
# 116  2.137534    0.226560  0.105966
# 117  2.136769    0.228937  0.107464
# 118  2.119266    0.226317  0.104592
# 119  2.134894    0.236858  0.108482
#
# [120 rows x 3 columns]

# %%
# !pwd
# Out:
# /home/arima/tomoe/tomoeflash/script

# %%
fig, ax = plt.subplots()
ax.set_title('Tomo-e (stack - frame) diff. imgs (with my CentOS7.9 PC)')
ax.set_xlabel('Frame number')
ax.set_ylabel('Time (sec)')
df_time.plot(ax=ax)
# Out:
# <AxesSubplot:title={'center':'Tomo-e (stack - frame) diff. imgs (with my CentOS7.9 PC)'}, xlabel='Frame number', ylabel='Time (sec)'>
